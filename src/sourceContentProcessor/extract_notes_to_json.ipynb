# %%
from pathlib import Path
import os

from sourceContentProcessor.extraction_runner import extract_biology_notes

# %%
BASE_DIR_PATH = Path.cwd().parent.parent
NOTES_PATH = BASE_DIR_PATH / "docs"   / "Notes"
print(NOTES_PATH)

OUTPUT_BASE_DIR = BASE_DIR_PATH / "docs" / "extracted_source_content" 
print(OUTPUT_BASE_DIR)
# Out:
# c:\Users\Motunrayo Ibiyo\Documents\IBrary\docs\Notes
# c:\Users\Motunrayo Ibiyo\Documents\IBrary\docs\extracted_source_content

# %%
subject = "biology"
extraction_type = "notes"

# %%
first_term_biology_rft_notes = NOTES_PATH / "1ST TERM S1 BIOLOGY.rtf"
first_term_biology_pdf_notes = NOTES_PATH / "1ST TERM S1 BIOLOGY.pdf"
first_term_biology_md_notes = NOTES_PATH / "1ST TERM S1 BIOLOGY.md"

# %%
output_dir = OUTPUT_BASE_DIR / subject / extraction_type
biology_notes = extract_biology_notes(md_path=first_term_biology_md_notes,
                      output_dir=output_dir,
                      rtf_path=first_term_biology_rft_notes,
                      pdf_path=first_term_biology_pdf_notes)
